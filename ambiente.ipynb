# %% [markdown]
# # Colab

# %% [markdown]
# <video width="320" height="240" controls>
#   <source src="https://1drv.ms/v/c/808ebfd9a0d86213/IQCvd0JdCvYGRbvnz5dAT3RLAd9ut2Ay2zsdX9M1o1oKRPo?e=yYlxX0" type="video/mp4">
# </video>

# %% [markdown]
# # Python Local
