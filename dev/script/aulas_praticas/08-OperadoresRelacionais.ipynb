# %%
'Python' != "Python"
# Out:
# False

# %%
0 == obj_bool
# Out:
# True

# %%
1.0 == True
# Out:
# True

# %%
0.0 == False
# Out:
# True

# %%
"1.0" == 1.0
# Out:
# False

# %%
"1" == 1.0
# Out:
# False

# %%
"0" == False
# Out:
# False

# %%
1 == "True"
# Out:
# False

# %%
0 < 2 <= 3
# Out:
# True

# %%
3 >= 2 > 0
# Out:
# True

# %%
import numpy as np
import pandas as pd

# %%
obj_tupla = tuple(np.random.randint(1, 10, 6))
obj_tupla_I = obj_tupla[:]
obj_tupla_II = obj_tupla[:]
print(f"{obj_tupla_I}\n{obj_tupla_II}")
# Out:
# (5, 6, 3, 8, 8, 5)
# (5, 6, 3, 8, 8, 5)

# %%
obj_tupla_I == obj_tupla_II
# Out:
# True

# %%
obj_lista_II = list(obj_tupla_II)
obj_lista_II
# Out:
# [5, 6, 3, 8, 8, 5]

# %%
obj_tupla_I == obj_lista_II
# Out:
# False

# %%
obj_tupla_I = tuple(np.random.randint(1, 10, 6))
obj_tupla_II = tuple(np.random.randint(1, 10, 6))
print(f"{obj_tupla_I}\n{obj_tupla_II}")
# Out:
# (8, 1, 7, 2, 6, 2)
# (9, 4, 7, 4, 8, 2)

# %%
obj_tupla_I == obj_tupla_II
# Out:
# False

# %%
obj_list_I = list(np.random.randint(1, 10, 6))
obj_list_II = list(np.random.randint(1, 10, 6))
print(f"{obj_list_I == obj_list_II}")
# Out:
# False

# %%
obj_numpy_I = np.random.randint(1, 10, 6)
obj_numpy_II = np.random.randint(1, 10, 6)
print(f"{obj_numpy_I}\n{obj_numpy_II}")
# Out:
# [3 6 1 1 8 6]
# [6 3 1 5 5 7]

# %%
obj_numpy_I == obj_numpy_II
# Out:
# array([False, False,  True, False, False, False])

# %%
obj_numpy_I[obj_numpy_I == obj_numpy_II]
# Out:
# array([1])

# %%
obj_numpy_I[obj_numpy_I != obj_numpy_II]
# Out:
# array([3, 6, 1, 8, 6])

# %%
obj_numpy_I[obj_numpy_I >= obj_numpy_II]
# Out:
# array([6, 1, 8])

# %%
obj_numpy_I
# Out:
# array([3, 6, 1, 1, 8, 6])

# %%
obj_numpy_I != 1
# Out:
# array([ True,  True, False, False,  True,  True])

# %%
obj_numpy_I >= 5
# Out:
# array([False,  True, False, False,  True,  True])

# %%
array = np.asarray(
    [obj_numpy_I,
    obj_numpy_II,
    obj_numpy_I,
    obj_numpy_II,
    obj_numpy_I,
    obj_numpy_II,]
)
array
# Out:
# array([[3, 6, 1, 1, 8, 6],
#        [6, 3, 1, 5, 5, 7],
#        [3, 6, 1, 1, 8, 6],
#        [6, 3, 1, 5, 5, 7],
#        [3, 6, 1, 1, 8, 6],
#        [6, 3, 1, 5, 5, 7]])

# %%
obj_data = pd.DataFrame(array)
obj_data
# Out:
#    0  1  2  3  4  5
# 0  3  6  1  1  8  6
# 1  6  3  1  5  5  7
# 2  3  6  1  1  8  6
# 3  6  3  1  5  5  7
# 4  3  6  1  1  8  6
# 5  6  3  1  5  5  7

# %%
obj_data == 1
# Out:
#        0      1     2      3      4      5
# 0  False  False  True   True  False  False
# 1  False  False  True  False  False  False
# 2  False  False  True   True  False  False
# 3  False  False  True  False  False  False
# 4  False  False  True   True  False  False
# 5  False  False  True  False  False  False

# %%
obj_data[(1 < obj_data) & (obj_data <= 5)]
# Out:
#      0    1   2    3    4   5
# 0  3.0  NaN NaN  NaN  NaN NaN
# 1  NaN  3.0 NaN  5.0  5.0 NaN
# 2  3.0  NaN NaN  NaN  NaN NaN
# 3  NaN  3.0 NaN  5.0  5.0 NaN
# 4  3.0  NaN NaN  NaN  NaN NaN
# 5  NaN  3.0 NaN  5.0  5.0 NaN

# %%
obj_data > 2
# Out:
#       0     1      2      3     4     5
# 0  True  True  False  False  True  True
# 1  True  True  False   True  True  True
# 2  True  True  False  False  True  True
# 3  True  True  False   True  True  True
# 4  True  True  False  False  True  True
# 5  True  True  False   True  True  True

# %%
obj_data[obj_data > 2]
# Out:
#    0  1   2    3  4  5
# 0  3  6 NaN  NaN  8  6
# 1  6  3 NaN  5.0  5  7
# 2  3  6 NaN  NaN  8  6
# 3  6  3 NaN  5.0  5  7
# 4  3  6 NaN  NaN  8  6
# 5  6  3 NaN  5.0  5  7

# %%
obj_data[0] > 3
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4    False
# 5     True
# Name: 0, dtype: bool

# %%
obj_data.loc[4] != 1
# Out:
# 0     True
# 1     True
# 2    False
# 3    False
# 4     True
# 5     True
# Name: 4, dtype: bool

# %%
obj_data == obj_numpy_II
# Out:
#        0      1     2      3      4      5
# 0  False  False  True  False  False  False
# 1   True   True  True   True   True   True
# 2  False  False  True  False  False  False
# 3   True   True  True   True   True   True
# 4  False  False  True  False  False  False
# 5   True   True  True   True   True   True

# %%
obj_data
# Out:
#    0  1  2  3  4  5
# 0  3  6  1  1  8  6
# 1  6  3  1  5  5  7
# 2  3  6  1  1  8  6
# 3  6  3  1  5  5  7
# 4  3  6  1  1  8  6
# 5  6  3  1  5  5  7

# %%
obj_numpy_II
# Out:
# array([6, 3, 1, 5, 5, 7])

# %%
len(obj_data == obj_numpy_II)
# Out:
# 6

# %%
len(obj_data)
# Out:
# 6

# %%
obj_data == obj_numpy_II
# Out:
#        0      1     2      3      4      5
# 0  False  False  True  False  False  False
# 1   True   True  True   True   True   True
# 2  False  False  True  False  False  False
# 3   True   True  True   True   True   True
# 4  False  False  True  False  False  False
# 5   True   True  True   True   True   True
