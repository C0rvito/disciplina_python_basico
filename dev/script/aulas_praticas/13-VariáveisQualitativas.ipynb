# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def df_nominal_rand():
    nomes = np.array(['Cepa A','Cepa B','Cepa C','Cepa D','Total'])
    freqAbSimpl = np.random.randint(100,1000,4)
    freqAbSimpl = np.append(freqAbSimpl, sum(freqAbSimpl))
    freqRelSimpl = np.array([round(i/freqAbSimpl[-1], 2) for i in freqAbSimpl])
    columns=['Freq Absol Simp','Freq Relat Simp',]
    df_nominal = pd.DataFrame(columns=columns, index=nomes)
    df_nominal[df_nominal.columns[0]] = freqAbSimpl
    df_nominal[df_nominal.columns[1]] = freqRelSimpl
    return df_nominal

# %%
def df_ordinal_rand():
    nomes = np.array(['Concent A','Concent B','Concent C','Concent D','Total'])
    freqAbSimpl = np.random.randint(100,1000,4)
    freqAbSimpl = np.append(freqAbSimpl, sum(freqAbSimpl))
    freqRelSimpl = np.array([round(i/freqAbSimpl[-1], 2) for i in freqAbSimpl])
    freqAbAcum = []
    conta = 0
    for i in freqAbSimpl[:-1]:
        conta += i
        freqAbAcum.append(conta)
    freqAbAcum.append(np.nan)
    freqRelAcum = np.array([round(i/freqAbAcum[-2], 2) for i in freqAbAcum])
    columns=['Freq Absol Simp','Freq Relat Simp','Freq Absol Acum','Freq Relat Acum']
    df_ordinal = pd.DataFrame(columns=columns, index=nomes)
    df_ordinal[df_ordinal.columns[0]] = freqAbSimpl
    df_ordinal[df_ordinal.columns[1]] = freqRelSimpl
    df_ordinal[df_ordinal.columns[2]] = freqAbAcum
    df_ordinal[df_ordinal.columns[3]] = freqRelAcum
    return df_ordinal

# %%
df_nominal = df_nominal_rand()
df_nominal
# Out:
#         Freq Absol Simp  Freq Relat Simp
# Cepa A              410             0.19
# Cepa B              693             0.32
# Cepa C              405             0.19
# Cepa D              639             0.30
# Total              2147             1.00

# %%
columns=[
    'Freq Absol Simp',
    'Freq Relat Simp',
    'Freq Absol Acum',
    'Freq Relat Acum'
    ]
df_nominal.iloc[:-1].plot(
    kind='pie',
    y=columns[0],
    explode=(0.1,0.1,0.1,0.1),
    startangle=90,
    shadow=True,
)
print_img = False
if(print_img):
    plt.savefig('figuras/13-Variáveis_Qualitativas_pie.png', transparent=True, bbox_inches='tight')
plt.show()

# %%
a, b, c, d, e = df_nominal[columns[1]].values
plt.bar(columns[1], a, color='b')
plt.bar(columns[1], b, color='orange', bottom=a)
plt.bar(columns[1], c, color='g', bottom=a+b)
plt.bar(columns[1], d, color='r', bottom=a+b+c)
plt.legend(df_nominal[columns[1]].index)
plt.ylabel('Frequência')
if(print_img):
    plt.savefig('figuras/13-Variáveis_Qualitativas_bar.png', transparent=True, bbox_inches='tight')
plt.show()

# %%
df_ordinal_I = df_ordinal_rand()
df_ordinal_I
# Out:
#            Freq Absol Simp  Freq Relat Simp  Freq Absol Acum  Freq Relat Acum
# Concent A              386             0.17            386.0             0.17
# Concent B              158             0.07            544.0             0.24
# Concent C              799             0.35           1343.0             0.59
# Concent D              935             0.41           2278.0             1.00
# Total                 2278             1.00              NaN              NaN

# %%
df_ordinal_I[:-1][[columns[0],columns[2]]].plot()
plt.xlabel("Concentrações teste")
plt.ylabel("Número de ocorrências")
if(print_img):
    plt.savefig('figuras/13-Variáveis_Qualitativas_line_i.png', transparent=True, bbox_inches='tight')
plt.show()

# %%
df_ordinal_I[:-1][[columns[1],columns[3]]].plot()
plt.xlabel("Concentrações teste")
plt.ylabel("Frequencia de ocorrências")
if(print_img):
    plt.savefig('figuras/13-Variáveis_Qualitativas_line_ii.png', transparent=True, bbox_inches='tight')
plt.show()

# %%
sns.catplot(
    kind='bar',
    x=list(df_ordinal_I[columns[0]].index)[:-1],
    y=columns[0],
    data=df_ordinal_I.iloc[:-1],
)
plt.xlabel("Concentrações teste")
if(print_img):
    plt.savefig('figuras/13-Variáveis_Qualitativas_bar_simples_i.png', transparent=True, bbox_inches='tight')
plt.show()

# %%
sns.catplot(
    kind='bar',
    x=list(df_ordinal_I[columns[1]].index)[:-1],
    y=columns[1],
    data=df_ordinal_I.iloc[:-1],
)
plt.xlabel("Concentrações teste")
if(print_img):
    plt.savefig('figuras/13-Variáveis_Qualitativas_bar_simples_ii.png', transparent=True, bbox_inches='tight')
plt.show()

# %%
sns.catplot(
    kind='bar',
    x=list(df_ordinal_I[columns[2]].index)[:-1],
    y=columns[2],
    data=df_ordinal_I.iloc[:-1],
)
plt.xlabel("Concentrações teste")
if(print_img):
    plt.savefig('figuras/13-Variáveis_Qualitativas_bar_simples_iii.png', transparent=True, bbox_inches='tight')
plt.show()

# %%
sns.catplot(
    kind='bar',
    x=list(df_ordinal_I[columns[3]].index)[:-1],
    y=columns[3],
    data=df_ordinal_I.iloc[:-1],
)
plt.xlabel("Concentrações teste")
if(print_img):
    plt.savefig('figuras/13-Variáveis_Qualitativas_bar_simples_iv.png', transparent=True, bbox_inches='tight')
plt.show()

# %%
df_ordinal_II = df_ordinal_rand()
df_ordinal_II
# Out:
#            Freq Absol Simp  Freq Relat Simp  Freq Absol Acum  Freq Relat Acum
# Concent A              994             0.31            994.0             0.31
# Concent B              712             0.22           1706.0             0.53
# Concent C              695             0.22           2401.0             0.75
# Concent D              811             0.25           3212.0             1.00
# Total                 3212             1.00              NaN              NaN

# %%
df_ordinal_I['Replica'] = 'Replica A'
df_ordinal_II['Replica'] = 'Replica B'
df_ordinal_replica_I = pd.concat([df_ordinal_I,df_ordinal_II], axis=0).reset_index()
df_ordinal_replica_I.rename(columns={'index': 'Concentração'}, inplace=True)
df_ordinal_replica_I
# Out:
#   Concentração  Freq Absol Simp  Freq Relat Simp  Freq Absol Acum  \
# 0    Concent A              386             0.17            386.0
# 1    Concent B              158             0.07            544.0
# 2    Concent C              799             0.35           1343.0
# 3    Concent D              935             0.41           2278.0
# 4        Total             2278             1.00              NaN
# 5    Concent A              994             0.31            994.0
# 6    Concent B              712             0.22           1706.0
# 7    Concent C              695             0.22           2401.0
# 8    Concent D              811             0.25           3212.0
# 9        Total             3212             1.00              NaN
#
#    Freq Relat Acum    Replica
# 0             0.17  Replica A
# 1             0.24  Replica A
# 2             0.59  Replica A
# 3             1.00  Replica A
# 4              NaN  Replica A
# 5             0.31  Replica B
# 6             0.53  Replica B
# 7             0.75  Replica B
# 8             1.00  Replica B
# 9              NaN  Replica B

# %%
sns.catplot(
    kind='bar',
    x=df_ordinal_replica_I.columns[-1],
    y=columns[0],
    hue=df_ordinal_replica_I.columns[0],
    height=10,
    data=df_ordinal_replica_I.dropna()
)
plt.xlabel('Concentrações testes')
if(print_img):
    plt.savefig('figuras/13-Variáveis_Qualitativas_bar_replicas_i.png', transparent=True, bbox_inches='tight')
plt.show()

# %%
df_ordinal_III = df_ordinal_rand()
df_ordinal_IV = df_ordinal_rand()
df_ordinal_III['Replica'] = 'Replica A'
df_ordinal_IV['Replica'] = 'Replica B'
df_ordinal_replica_II = pd.concat([df_ordinal_III,df_ordinal_IV], axis=0).reset_index()
df_ordinal_replica_II.rename(columns={'index': 'Concentração'}, inplace=True)
df_ordinal_replica_II
# Out:
#   Concentração  Freq Absol Simp  Freq Relat Simp  Freq Absol Acum  \
# 0    Concent A              230             0.14            230.0
# 1    Concent B              193             0.12            423.0
# 2    Concent C              801             0.48           1224.0
# 3    Concent D              436             0.26           1660.0
# 4        Total             1660             1.00              NaN
# 5    Concent A              320             0.14            320.0
# 6    Concent B              944             0.40           1264.0
# 7    Concent C              308             0.13           1572.0
# 8    Concent D              790             0.33           2362.0
# 9        Total             2362             1.00              NaN
#
#    Freq Relat Acum    Replica
# 0             0.14  Replica A
# 1             0.25  Replica A
# 2             0.74  Replica A
# 3             1.00  Replica A
# 4              NaN  Replica A
# 5             0.14  Replica B
# 6             0.54  Replica B
# 7             0.67  Replica B
# 8             1.00  Replica B
# 9              NaN  Replica B

# %%
df_ordinal_replica_I['Teste'] = 'Teste 1'
df_ordinal_replica_II['Teste'] = 'Teste 2'
df_ordinal_replica = pd.concat([df_ordinal_replica_I,df_ordinal_replica_II], axis=0).reset_index()
del(df_ordinal_replica['index'])
df_ordinal_replica
# Out:
#    Concentração  Freq Absol Simp  Freq Relat Simp  Freq Absol Acum  \
# 0     Concent A              386             0.17            386.0
# 1     Concent B              158             0.07            544.0
# 2     Concent C              799             0.35           1343.0
# 3     Concent D              935             0.41           2278.0
# 4         Total             2278             1.00              NaN
# 5     Concent A              994             0.31            994.0
# 6     Concent B              712             0.22           1706.0
# 7     Concent C              695             0.22           2401.0
# 8     Concent D              811             0.25           3212.0
# 9         Total             3212             1.00              NaN
# 10    Concent A              230             0.14            230.0
# 11    Concent B              193             0.12            423.0
# 12    Concent C              801             0.48           1224.0
# 13    Concent D              436             0.26           1660.0
# 14        Total             1660             1.00              NaN
# 15    Concent A              320             0.14            320.0
# 16    Concent B              944             0.40           1264.0
# 17    Concent C              308             0.13           1572.0
# 18    Concent D              790             0.33           2362.0
# 19        Total             2362             1.00              NaN
#
#     Freq Relat Acum    Replica    Teste
# 0              0.17  Replica A  Teste 1
# 1              0.24  Replica A  Teste 1
# 2              0.59  Replica A  Teste 1
# 3              1.00  Replica A  Teste 1
# 4               NaN  Replica A  Teste 1
# 5              0.31  Replica B  Teste 1
# 6              0.53  Replica B  Teste 1
# 7              0.75  Replica B  Teste 1
# 8              1.00  Replica B  Teste 1
# 9               NaN  Replica B  Teste 1
# 10             0.14  Replica A  Teste 2
# 11             0.25  Replica A  Teste 2
# 12             0.74  Replica A  Teste 2
# 13             1.00  Replica A  Teste 2
# 14              NaN  Replica A  Teste 2
# 15             0.14  Replica B  Teste 2
# 16             0.54  Replica B  Teste 2
# 17             0.67  Replica B  Teste 2
# 18             1.00  Replica B  Teste 2
# 19              NaN  Replica B  Teste 2

# %%
sns.catplot(
    kind='bar',
    x=df_ordinal_replica.columns[-2],
    y=df_ordinal_replica.columns[1],
    hue=df_ordinal_replica.columns[0],
    height=10,
    data=df_ordinal_replica.dropna()
)
if(print_img):
    plt.savefig('figuras/13-Variáveis_Qualitativas_bar_replicas_ii.png', transparent=True, bbox_inches='tight')
plt.show()
