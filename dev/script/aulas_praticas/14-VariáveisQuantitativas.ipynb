# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def df_discretas_rand(nomes):
    freqAbSimpl = np.random.randint(100,1000,len(nomes))
    nomes.append('Total')
    freqAbSimpl = np.append(freqAbSimpl, sum(freqAbSimpl))
    freqRelSimpl = np.array([round(i/freqAbSimpl[-1], 2) for i in freqAbSimpl])
    freqAbAcum = []
    conta = 0
    for i in freqAbSimpl[:-1]:
        conta += i
        freqAbAcum.append(conta)
    freqAbAcum.append(np.nan)
    freqRelAcum = np.array([round(i/freqAbAcum[-2], 2) for i in freqAbAcum])
    columns=['Freq Absol Simp','Freq Relat Simp','Freq Absol Acum','Freq Relat Acum']
    df_ordinal = pd.DataFrame(columns=columns, index=nomes)
    df_ordinal[df_ordinal.columns[0]] = freqAbSimpl
    df_ordinal[df_ordinal.columns[1]] = freqRelSimpl
    df_ordinal[df_ordinal.columns[2]] = freqAbAcum
    df_ordinal[df_ordinal.columns[3]] = freqRelAcum
    return df_ordinal

# %%
nomes = ['CD4','CD8/CD4','CD19/CD8/CD4','CD14/CD19/CD8/CD4']
df_discreta = df_discretas_rand(nomes)
df_discreta
# Out:
#                    Freq Absol Simp  Freq Relat Simp  Freq Absol Acum  \
# CD4                            761             0.44            761.0
# CD8/CD4                        271             0.16           1032.0
# CD19/CD8/CD4                   502             0.29           1534.0
# CD14/CD19/CD8/CD4              180             0.11           1714.0
# Total                         1714             1.00              NaN
#
#                    Freq Relat Acum
# CD4                           0.44
# CD8/CD4                       0.60
# CD19/CD8/CD4                  0.89
# CD14/CD19/CD8/CD4             1.00
# Total                          NaN

# %%
c = 1
sns.catplot(
    kind='bar',
    x=list(df_discreta[df_discreta.columns[c]].index)[:-1],
    y=df_discreta.columns[c],
    data=df_discreta.iloc[:-1],
)
plt.xticks(rotation=45)
plt.xlabel("Concentrações teste")
print_img = True
if(print_img):
    plt.savefig('figuras/14-Variáveis_Quantitativas_bar_simples_i.png', transparent=True, bbox_inches='tight')
plt.show()

# %%
c = 3
sns.catplot(
    kind='bar',
    x=list(df_discreta[df_discreta.columns[c]].index)[:-1],
    y=df_discreta.columns[c],
    data=df_discreta.iloc[:-1],
)
plt.xticks(rotation=45)
plt.xlabel("Concentrações teste")
if(print_img):
    plt.savefig('figuras/14-Variáveis_Quantitativas_bar_simples_ii.png', transparent=True, bbox_inches='tight')
plt.show()

# %%
nomes = [i for i in range(1,101)]
df_discreta = df_discretas_rand(nomes)
df_discreta
# Out:
#        Freq Absol Simp  Freq Relat Simp  Freq Absol Acum  Freq Relat Acum
# 1                  658             0.01            658.0             0.01
# 2                  106             0.00            764.0             0.01
# 3                  582             0.01           1346.0             0.02
# 4                  708             0.01           2054.0             0.04
# 5                  940             0.02           2994.0             0.05
# ...                ...              ...              ...              ...
# 97                 174             0.00          53510.0             0.97
# 98                 641             0.01          54151.0             0.98
# 99                 504             0.01          54655.0             0.99
# 100                625             0.01          55280.0             1.00
# Total            55280             1.00              NaN              NaN
#
# [101 rows x 4 columns]

# %%
c = 1
sns.catplot(
    kind='bar',
    x=list(df_discreta[df_discreta.columns[c]].index)[:-1],
    y=df_discreta.columns[c],
    data=df_discreta.iloc[:-1],
)
plt.xlabel("Concentrações teste")
if(print_img):
    plt.savefig('figuras/14-Variáveis_Quantitativas_bar_simples_iii.png', transparent=True, bbox_inches='tight')
plt.show()

# %%
c = 3
sns.catplot(
    kind='bar',
    x=list(df_discreta[df_discreta.columns[c]].index)[:-1],
    y=df_discreta.columns[c],
    data=df_discreta.iloc[:-1],
)
plt.xlabel("Concentrações teste")
if(print_img):
    plt.savefig('figuras/14-Variáveis_Quantitativas_bar_simples_iv.png', transparent=True, bbox_inches='tight')
plt.show()

# %%
nomes = [i for i in range(1,11)]
df_discreta = df_discretas_rand(nomes)
df_discreta
# Out:
#        Freq Absol Simp  Freq Relat Simp  Freq Absol Acum  Freq Relat Acum
# 1                  440             0.08            440.0             0.08
# 2                  134             0.02            574.0             0.10
# 3                  203             0.03            777.0             0.13
# 4                  631             0.11           1408.0             0.24
# 5                  818             0.14           2226.0             0.38
# 6                  587             0.10           2813.0             0.48
# 7                  839             0.14           3652.0             0.63
# 8                  476             0.08           4128.0             0.71
# 9                  931             0.16           5059.0             0.87
# 10                 772             0.13           5831.0             1.00
# Total             5831             1.00              NaN              NaN

# %%
c = 1
sns.catplot(
    kind='bar',
    x=list(df_discreta[df_discreta.columns[c]].index)[:-1],
    y=df_discreta.columns[c],
    data=df_discreta.iloc[:-1],
)
plt.xlabel("Concentrações teste")
if(print_img):
    plt.savefig('figuras/14-Variáveis_Quantitativas_bar_simples_v.png', transparent=True, bbox_inches='tight')
plt.show()

# %%
c = 3
sns.catplot(
    kind='bar',
    x=list(df_discreta[df_discreta.columns[c]].index)[:-1],
    y=df_discreta.columns[c],
    data=df_discreta.iloc[:-1],
)
plt.xlabel("Concentrações teste")
if(print_img):
    plt.savefig('figuras/14-Variáveis_Quantitativas_bar_simples_vi.png', transparent=True, bbox_inches='tight')
plt.show()

# %%
def gera_numeros():
    return str(round(np.random.rand()+
    np.random.randint(10), 2)) + "%"

# %%
nomes = [str(gera_numeros()[0])+'%' 
for _ in range(10)]
freqAbSimpl = np.random.randint(0, 1_000, 10)
df_discreta = tabelaFrequencia(freqAbSimpl, nomes)
df_discreta

# %%
c = 0
sns.histplot(
    x=df_discreta.columns[c],
    kde=True,
    element="poly",
    data=df_discreta.dropna()
)
plt.ylabel('Número')
plt.show()

# %%
df_discreta[df_discreta.columns[[0,2]]].plot()
plt.ylabel('Freq Absol')
plt.show()

# %%
nomes = [gera_numeros() for _ in range(10)]
df_discreta = df_discretas_rand(nomes)
df_discreta
# Out:
#        Freq Absol Simp  Freq Relat Simp  Freq Absol Acum  Freq Relat Acum
# 8.19%              209             0.03            209.0             0.03
# 2.74%              751             0.13            960.0             0.16
# 6.72%              196             0.03           1156.0             0.19
# 5.79%              457             0.08           1613.0             0.27
# 2.99%              625             0.10           2238.0             0.37
# 6.88%              607             0.10           2845.0             0.47
# 3.34%              852             0.14           3697.0             0.62
# 7.06%              939             0.16           4636.0             0.77
# 3.78%              593             0.10           5229.0             0.87
# 8.81%              776             0.13           6005.0             1.00
# Total             6005             1.00              NaN              NaN

# %%
c = 0
sns.histplot(
    x=df_discreta.columns[c],
    kde=True,
    element="poly",
    data=df_discreta.dropna()
)
plt.ylabel('Número')
if(print_img):
    plt.savefig('figuras/14-Variáveis_Quantitativas_hist_simples_i.png', transparent=True, bbox_inches='tight')
plt.show()

# %%
df_discreta[df_discreta.columns[[0,2]]].plot()
plt.ylabel('Freq Absol')
if(print_img):
    plt.savefig('figuras/14-Variáveis_Quantitativas_plot_simples_i.png', transparent=True, bbox_inches='tight')
plt.show()
