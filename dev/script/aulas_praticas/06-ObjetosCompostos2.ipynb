# %%
simbolo = ['IFNG','Il10','Tnf','CSF2']
full_name = [
    'interferon gamma',
    'interleukin 10',
    'tumor necrosis factor',
    'colony stimulating factor 2'
]
source = ['HGNC:HGNC:5438','RGD:2886','MGI:MGI:104798','HGNC:HGNC:2434']
gene_type = ['protein coding','protein coding','protein coding','protein coding']
organism = ['Homo sapiens','Rattus norvegicus','Mus musculus','Homo sapiens']
chromosome = [12,13,17,5]

# %%
gene_matriz_lista = [
    simbolo,
    full_name,
    source,
    gene_type,
    organism,
    chromosome
]
gene_matriz_lista
# Out:
# [['IFNG', 'Il10', 'Tnf', 'CSF2'],
#  ['interferon gamma',
#   'interleukin 10',
#   'tumor necrosis factor',
#   'colony stimulating factor 2'],
#  ['HGNC:HGNC:5438', 'RGD:2886', 'MGI:MGI:104798', 'HGNC:HGNC:2434'],
#  ['protein coding', 'protein coding', 'protein coding', 'protein coding'],
#  ['Homo sapiens', 'Rattus norvegicus', 'Mus musculus', 'Homo sapiens'],
#  [12, 13, 17, 5]]

# %%
gene_matriz_disc = {
    'Símbolos': simbolo,
    'Nomes completos': full_name,
    'Origem': source,
    'Tipo': gene_type,
    'Organismo': organism,
    'Cromossomo': chromosome
}
gene_matriz_disc
# Out:
# {'Símbolos': ['IFNG', 'Il10', 'Tnf', 'CSF2'],
#  'Nomes completos': ['interferon gamma',
#   'interleukin 10',
#   'tumor necrosis factor',
#   'colony stimulating factor 2'],
#  'Origem': ['HGNC:HGNC:5438', 'RGD:2886', 'MGI:MGI:104798', 'HGNC:HGNC:2434'],
#  'Tipo': ['protein coding',
#   'protein coding',
#   'protein coding',
#   'protein coding'],
#  'Organismo': ['Homo sapiens',
#   'Rattus norvegicus',
#   'Mus musculus',
#   'Homo sapiens'],
#  'Cromossomo': [12, 13, 17, 5]}

# %%
gene_matriz_disc['Símbolos']
# Out:
# ['IFNG', 'Il10', 'Tnf', 'CSF2']

# %%
gene_matriz_disc['Cromossomo']
# Out:
# [12, 13, 17, 5]

# %%
simbolo.append('Il6')
simbolo
# Out:
# ['IFNG', 'Il10', 'Tnf', 'CSF2', 'Il6']

# %%
gene_matriz_disc['Símbolos']
# Out:
# ['IFNG', 'Il10', 'Tnf', 'CSF2', 'Il6']

# %%
simbolo.insert(1, 'IFNB')
gene_matriz_disc['Símbolos']
# Out:
# ['IFNG', 'IFNB', 'Il10', 'Tnf', 'CSF2', 'Il6']

# %%
simbolo.remove('IFNB')
gene_matriz_disc['Símbolos']
# Out:
# ['IFNG', 'Il10', 'Tnf', 'CSF2', 'Il6']

# %%
simbolo.pop()
gene_matriz_disc['Símbolos']
# Out:
# ['IFNG', 'Il10', 'Tnf', 'CSF2']

# %%
import numpy as np

# %%
gene_matriz_lista
# Out:
# [['IFNG', 'Il10', 'Tnf', 'CSF2'],
#  ['interferon gamma',
#   'interleukin 10',
#   'tumor necrosis factor',
#   'colony stimulating factor 2'],
#  ['HGNC:HGNC:5438', 'RGD:2886', 'MGI:MGI:104798', 'HGNC:HGNC:2434'],
#  ['protein coding', 'protein coding', 'protein coding', 'protein coding'],
#  ['Homo sapiens', 'Rattus norvegicus', 'Mus musculus', 'Homo sapiens'],
#  [12, 13, 17, 5]]

# %%
gene_matriz_array = np.asarray(gene_matriz_lista)
gene_matriz_array
# Out:
# array([['IFNG', 'Il10', 'Tnf', 'CSF2'],
#        ['interferon gamma', 'interleukin 10', 'tumor necrosis factor',
#         'colony stimulating factor 2'],
#        ['HGNC:HGNC:5438', 'RGD:2886', 'MGI:MGI:104798', 'HGNC:HGNC:2434'],
#        ['protein coding', 'protein coding', 'protein coding',
#         'protein coding'],
#        ['Homo sapiens', 'Rattus norvegicus', 'Mus musculus',
#         'Homo sapiens'],
#        ['12', '13', '17', '5']], dtype='<U27')

# %%
gene_matriz_array[[0,2,-1]]
# Out:
# array([['IFNG', 'Il10', 'Tnf', 'CSF2'],
#        ['HGNC:HGNC:5438', 'RGD:2886', 'MGI:MGI:104798', 'HGNC:HGNC:2434'],
#        ['12', '13', '17', '5']], dtype='<U27')

# %%
gene_matriz_array[:,-1]
# Out:
# array(['CSF2', 'colony stimulating factor 2', 'HGNC:HGNC:2434',
#        'protein coding', 'Homo sapiens', '5'], dtype='<U27')

# %%
gene_matriz_array[-1,:]
# Out:
# array(['12', '13', '17', '5'], dtype='<U27')

# %%
gene_matriz_array[[0,1],[3,0]]
# Out:
# array(['CSF2', 'interferon gamma'], dtype='<U27')

# %%
import pandas as pd

# %%
np.arange(4)
# Out:
# array([0, 1, 2, 3])

# %%
gene_matriz = pd.DataFrame(
    columns=np.arange(4),
    data=[simbolo, full_name, source, gene_type, organism, chromosome],
    index=[
            'Símbolos',
            'Nomes completo',
            'Origem',
            'Tipo',
            'Organismo',
            'Cromossomo'
    ]
)
gene_matriz
# Out:
#                                0                  1                      2  \
# Símbolos                    IFNG               Il10                    Tnf
# Nomes completo  interferon gamma     interleukin 10  tumor necrosis factor
# Origem            HGNC:HGNC:5438           RGD:2886         MGI:MGI:104798
# Tipo              protein coding     protein coding         protein coding
# Organismo           Homo sapiens  Rattus norvegicus           Mus musculus
# Cromossomo                    12                 13                     17
#
#                                           3
# Símbolos                               CSF2
# Nomes completo  colony stimulating factor 2
# Origem                       HGNC:HGNC:2434
# Tipo                         protein coding
# Organismo                      Homo sapiens
# Cromossomo                                5

# %%
gene_matriz = gene_matriz.transpose()
gene_matriz
# Out:
#   Símbolos               Nomes completo          Origem            Tipo  \
# 0     IFNG             interferon gamma  HGNC:HGNC:5438  protein coding
# 1     Il10               interleukin 10        RGD:2886  protein coding
# 2      Tnf        tumor necrosis factor  MGI:MGI:104798  protein coding
# 3     CSF2  colony stimulating factor 2  HGNC:HGNC:2434  protein coding
#
#            Organismo Cromossomo
# 0       Homo sapiens         12
# 1  Rattus norvegicus         13
# 2       Mus musculus         17
# 3       Homo sapiens          5

# %%
gene_matriz.set_index('Símbolos', inplace=True)
gene_matriz
# Out:
#                        Nomes completo          Origem            Tipo  \
# Símbolos
# IFNG                 interferon gamma  HGNC:HGNC:5438  protein coding
# Il10                   interleukin 10        RGD:2886  protein coding
# Tnf             tumor necrosis factor  MGI:MGI:104798  protein coding
# CSF2      colony stimulating factor 2  HGNC:HGNC:2434  protein coding
#
#                   Organismo Cromossomo
# Símbolos
# IFNG           Homo sapiens         12
# Il10      Rattus norvegicus         13
# Tnf            Mus musculus         17
# CSF2           Homo sapiens          5

# %%
gene_matriz_lista = pd.DataFrame(gene_matriz_lista)
gene_matriz_lista
# Out:
#                   0                  1                      2  \
# 0              IFNG               Il10                    Tnf
# 1  interferon gamma     interleukin 10  tumor necrosis factor
# 2    HGNC:HGNC:5438           RGD:2886         MGI:MGI:104798
# 3    protein coding     protein coding         protein coding
# 4      Homo sapiens  Rattus norvegicus           Mus musculus
# 5                12                 13                     17
#
#                              3
# 0                         CSF2
# 1  colony stimulating factor 2
# 2               HGNC:HGNC:2434
# 3               protein coding
# 4                 Homo sapiens
# 5                            5

# %%
gene_matriz_lista = gene_matriz_lista.T
gene_matriz_lista
# Out:
#       0                            1               2               3  \
# 0  IFNG             interferon gamma  HGNC:HGNC:5438  protein coding
# 1  Il10               interleukin 10        RGD:2886  protein coding
# 2   Tnf        tumor necrosis factor  MGI:MGI:104798  protein coding
# 3  CSF2  colony stimulating factor 2  HGNC:HGNC:2434  protein coding
#
#                    4   5
# 0       Homo sapiens  12
# 1  Rattus norvegicus  13
# 2       Mus musculus  17
# 3       Homo sapiens   5

# %%
gene_matriz_lista.set_index(0, inplace=True)
gene_matriz_lista
# Out:
#                                 1               2               3  \
# 0
# IFNG             interferon gamma  HGNC:HGNC:5438  protein coding
# Il10               interleukin 10        RGD:2886  protein coding
# Tnf         tumor necrosis factor  MGI:MGI:104798  protein coding
# CSF2  colony stimulating factor 2  HGNC:HGNC:2434  protein coding
#
#                       4   5
# 0
# IFNG       Homo sapiens  12
# Il10  Rattus norvegicus  13
# Tnf        Mus musculus  17
# CSF2       Homo sapiens   5

# %%
gene_matriz_lista.columns = ['Nomes completo','Origem','Tipo','Organismo','Cromossomo']
gene_matriz_lista
# Out:
#                    Nomes completo          Origem            Tipo  \
# 0
# IFNG             interferon gamma  HGNC:HGNC:5438  protein coding
# Il10               interleukin 10        RGD:2886  protein coding
# Tnf         tumor necrosis factor  MGI:MGI:104798  protein coding
# CSF2  colony stimulating factor 2  HGNC:HGNC:2434  protein coding
#
#               Organismo Cromossomo
# 0
# IFNG       Homo sapiens         12
# Il10  Rattus norvegicus         13
# Tnf        Mus musculus         17
# CSF2       Homo sapiens          5

# %%
gene_matriz_data = pd.DataFrame(gene_matriz_disc).set_index('Símbolos')
gene_matriz_data
# Out:
#                       Nomes completos          Origem            Tipo  \
# Símbolos
# IFNG                 interferon gamma  HGNC:HGNC:5438  protein coding
# Il10                   interleukin 10        RGD:2886  protein coding
# Tnf             tumor necrosis factor  MGI:MGI:104798  protein coding
# CSF2      colony stimulating factor 2  HGNC:HGNC:2434  protein coding
#
#                   Organismo  Cromossomo
# Símbolos
# IFNG           Homo sapiens          12
# Il10      Rattus norvegicus          13
# Tnf            Mus musculus          17
# CSF2           Homo sapiens           5

# %%
gene_matriz_data['Origem']
# Out:
# Símbolos
# IFNG    HGNC:HGNC:5438
# Il10          RGD:2886
# Tnf     MGI:MGI:104798
# CSF2    HGNC:HGNC:2434
# Name: Origem, dtype: object

# %%
gene_matriz_data[['Origem', 'Tipo']]
# Out:
#                   Origem            Tipo
# Símbolos
# IFNG      HGNC:HGNC:5438  protein coding
# Il10            RGD:2886  protein coding
# Tnf       MGI:MGI:104798  protein coding
# CSF2      HGNC:HGNC:2434  protein coding

# %%
gene_matriz_data[['Tipo', 'Origem']]
# Out:
#                     Tipo          Origem
# Símbolos
# IFNG      protein coding  HGNC:HGNC:5438
# Il10      protein coding        RGD:2886
# Tnf       protein coding  MGI:MGI:104798
# CSF2      protein coding  HGNC:HGNC:2434

# %%
gene_matriz_data.loc['IFNG']
# Out:
# Nomes completos    interferon gamma
# Origem               HGNC:HGNC:5438
# Tipo                 protein coding
# Organismo              Homo sapiens
# Cromossomo                       12
# Name: IFNG, dtype: object

# %%
gene_matriz_data.loc[['Tnf', 'IFNG']]
# Out:
#                 Nomes completos          Origem            Tipo     Organismo  \
# Símbolos
# Tnf       tumor necrosis factor  MGI:MGI:104798  protein coding  Mus musculus
# IFNG           interferon gamma  HGNC:HGNC:5438  protein coding  Homo sapiens
#
#           Cromossomo
# Símbolos
# Tnf               17
# IFNG              12

# %%
gene_matriz_data.iloc[0]
# Out:
# Nomes completos    interferon gamma
# Origem               HGNC:HGNC:5438
# Tipo                 protein coding
# Organismo              Homo sapiens
# Cromossomo                       12
# Name: IFNG, dtype: object

# %%
gene_matriz_data.iloc[[2,0]]
# Out:
#                 Nomes completos          Origem            Tipo     Organismo  \
# Símbolos
# Tnf       tumor necrosis factor  MGI:MGI:104798  protein coding  Mus musculus
# IFNG           interferon gamma  HGNC:HGNC:5438  protein coding  Homo sapiens
#
#           Cromossomo
# Símbolos
# Tnf               17
# IFNG              12

# %%
gene_matriz_data[['Tipo','Origem']].iloc[[2,0]]
# Out:
#                     Tipo          Origem
# Símbolos
# Tnf       protein coding  MGI:MGI:104798
# IFNG      protein coding  HGNC:HGNC:5438

# %%
gene_matriz_data.iloc[:2]
# Out:
#            Nomes completos          Origem            Tipo          Organismo  \
# Símbolos
# IFNG      interferon gamma  HGNC:HGNC:5438  protein coding       Homo sapiens
# Il10        interleukin 10        RGD:2886  protein coding  Rattus norvegicus
#
#           Cromossomo
# Símbolos
# IFNG              12
# Il10              13

# %%
gene_matriz_data[gene_matriz_data['Cromossomo'] > 10]
# Out:
#                 Nomes completos          Origem            Tipo  \
# Símbolos
# IFNG           interferon gamma  HGNC:HGNC:5438  protein coding
# Il10             interleukin 10        RGD:2886  protein coding
# Tnf       tumor necrosis factor  MGI:MGI:104798  protein coding
#
#                   Organismo  Cromossomo
# Símbolos
# IFNG           Homo sapiens          12
# Il10      Rattus norvegicus          13
# Tnf            Mus musculus          17

# %%
gene_matriz_data.head(2)
# Out:
#            Nomes completos          Origem            Tipo          Organismo  \
# Símbolos
# IFNG      interferon gamma  HGNC:HGNC:5438  protein coding       Homo sapiens
# Il10        interleukin 10        RGD:2886  protein coding  Rattus norvegicus
#
#           Cromossomo
# Símbolos
# IFNG              12
# Il10              13

# %%
gene_matriz_data.tail(2)
# Out:
#                       Nomes completos          Origem            Tipo  \
# Símbolos
# Tnf             tumor necrosis factor  MGI:MGI:104798  protein coding
# CSF2      colony stimulating factor 2  HGNC:HGNC:2434  protein coding
#
#              Organismo  Cromossomo
# Símbolos
# Tnf       Mus musculus          17
# CSF2      Homo sapiens           5

# %%
gene_matriz_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, IFNG to CSF2
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Nomes completos  4 non-null      object
#  1   Origem           4 non-null      object
#  2   Tipo             4 non-null      object
#  3   Organismo        4 non-null      object
#  4   Cromossomo       4 non-null      int64
# dtypes: int64(1), object(4)
# memory usage: 364.0+ bytes

# %%
gene_matriz_data.describe()
# Out:
#        Cromossomo
# count     4.00000
# mean     11.75000
# std       4.99166
# min       5.00000
# 25%      10.25000
# 50%      12.50000
# 75%      14.00000
# max      17.00000

# %%
dir(gene_matriz_data)
# Out:
# ['Cromossomo',
#  'Organismo',
#  'Origem',
#  'T',
#  'Tipo',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
# ...
